# %%
import numpy as np 
import pandas as pd 
import seaborn as sns  
import matplotlib.pyplot as plt

# %%
url='https://raw.githubusercontent.com/nawinpoyen7/MachineLearning/main/DataSet/DataChange.csv'
df=pd.read_csv(url)
df.head(5)
# Out:
#        ID  Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0  462809       1             0   22          0           1                1
# 1  462643       0             1   38          1           3                1
# 2  466315       0             1   67          1           3                1
# 3  461735       1             1   67          1           5                0
# 4  462669       0             1   40          1           2                1
#
#    Spending_Score  Family_Size  Var_1 Segmentation
# 0               0            4      3            D
# 1               1            3      3            A
# 2               0            1      5            B
# 3               2            2      5            B
# 4               2            6      5            A

# %%
df.drop(['ID', 'Segmentation'], 1, inplace=True) # ลบทีละหลายคอลัมน์ก็ได้
# Out:
# C:\Users\yodrak\AppData\Local\Temp\ipykernel_10536\4174204234.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(['ID', 'Segmentation'], 1, inplace=True) # ลบทีละหลายคอลัมน์ก็ได้

# %%
df
# Out:
#       Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0          1             0   22          0           1                1
# 1          0             1   38          1           3                1
# 2          0             1   67          1           3                1
# 3          1             1   67          1           5                0
# 4          0             1   40          1           2                1
# ...      ...           ...  ...        ...         ...              ...
# 8063       1             0   22          0           5                0
# 8064       1             0   35          0           6                3
# 8065       0             0   33          1           1                1
# 8066       0             0   27          1           1                1
# 8067       1             1   37          1           6                0
#
#       Spending_Score  Family_Size  Var_1
# 0                  0            4      3
# ...

# %%
# save ข้อมูลทั้งหมดให้เป็นประเภท .csv และ .xls
df.to_csv('DeleteIDSEG.csv', index=False)
